# %% [markdown]
# ## Visualization of the superpixel images, graphs and edge connections

# %%
"""
    IMPORTING LIBS
"""
import numpy as np
import socket
import time
import networkx as nx
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("..") 
from data.data import LoadData # import dataset

# %%
print(testset[0])
# Out:
# <data.TUs.DGLFormDataset object at 0x7fd9b6afea90>

# %%
dataset = dgl.data.TUDataset("DD")
g, label = dataset[0]
options = {
    'node_color': 'black',
    'node_size': 20,
    'width': 1,
}
G = dgl.to_networkx(g)
plt.figure(figsize=[15,7])
nx.draw(G, **options)
